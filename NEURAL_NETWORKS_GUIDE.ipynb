# %% [markdown]
# # 🧠 Neural Networks (MLPClassifier & MLPRegressor) - Complete Learning Guide
#
# ## Overview
# Multi-Layer Perceptrons (MLPs) are fundamental neural networks with multiple layers of neurons connected by weights. They can learn complex non-linear patterns through backpropagation and can be used for both classification and regression.
#
# ## Key Topics Covered:
# 1. **Neural Network Basics** - Perceptrons, layers, neurons
# 2. **Activation Functions** - ReLU, tanh, logistic, identity
# 3. **Backpropagation** - How networks learn
# 4. **Architecture Design** - Hidden layers and units
# 5. **Learning Rates** - Impact on training
# 6. **Regularization** - L2 penalty, early stopping
# 7. **Classification vs Regression** - Different output layers
# 8. **Hyperparameter Tuning** - Optimal architecture and learning
#
# ---
#
# ## References:
# - [Neural Networks - Wikipedia](https://en.wikipedia.org/wiki/Artificial_neural_network)
# - [scikit-learn Neural Networks](https://scikit-learn.org/stable/modules/neural_networks.html)
# - [Backpropagation Explained](https://www.youtube.com/watch?v=Ilg3gGewQ5U)

# %% [markdown]
# ## 📚 Section 1: Import Libraries

# %%
# Import Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.datasets import load_iris, load_breast_cancer, make_classification, make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, roc_auc_score, mean_squared_error, r2_score
import warnings
warnings.filterwarnings('ignore')

# Set random seed
np.random.seed(42)

# Set matplotlib style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("✅ All libraries imported successfully!")

# %% [markdown]
# ## 🧠 Section 2: Neural Network Basics

# %%
# Example 1: Basic Neural Network Classification
print("\n" + "="*70)
print("🧠 EXAMPLE 1: Basic Neural Network Classification")
print("="*70)

# Load Iris
iris = load_iris()
X = iris.data
y = iris.target

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Neural Network
mlp = MLPClassifier(hidden_layer_sizes=(64, 32), activation='relu', 
                    max_iter=500, random_state=42)
mlp.fit(X_train_scaled, y_train)
y_pred = mlp.predict(X_test_scaled)

# Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"\n✅ MLP Classification Results (hidden=[64,32]):")
print(f"  Accuracy:  {accuracy:.4f}")
print(f"  Precision: {precision:.4f}")
print(f"  Recall:    {recall:.4f}")
print(f"  F1-Score:  {f1:.4f}")
print(f"  Architecture: [4] → [64] → [32] → [3]")
print(f"  Parameters: {mlp.n_layers_}")
print(f"  Converged: {mlp.n_iter_} iterations")

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax, cbar=False)
ax.set_xlabel('Predicted', fontsize=12, fontweight='bold')
ax.set_ylabel('Actual', fontsize=12, fontweight='bold')
ax.set_title(f'🧠 Neural Network Confusion Matrix (Acc={accuracy:.3f})', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ⚡ Section 3: Activation Functions

# %% [markdown]
# ## 🏗️ Section 4: Architecture Impact

# %%
## 📊 Section 5: Neural Network Regression
